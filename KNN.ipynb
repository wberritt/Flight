# %% [markdown]
# <a href="https://colab.research.google.com/github/wberritt/Projects/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1=pd.read_csv('adult.csv')
df1.head()
# Out:
#    age  workclass  fnlwgt  ... hours-per-week  native-country income
# 0   25    Private  226802  ...             40   United-States  <=50K
# 1   38    Private   89814  ...             50   United-States  <=50K
# 2   28  Local-gov  336951  ...             40   United-States   >50K
# 3   44    Private  160323  ...             40   United-States   >50K
# 4   18          ?  103497  ...             30   United-States  <=50K
#
# [5 rows x 15 columns]

# %%
df1.income = [1 if each=='>50K' else 0 for each in df1.income]
y = df1.income
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: income, Length: 48842, dtype: int64

# %%
df1['native-country'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        United-States
# 1        United-States
# 2        United-States
# 3        United-States
# 4        United-States
#              ...
# 48837    United-States
# 48838    United-States
# 48839    United-States
# 48840    United-States
# 48841    United-States
# Name: native-country, Length: 48842, dtype: object>

# %%
df1.drop(['native-country','fnlwgt'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    age  workclass     education  ...  capital-loss hours-per-week income
# 0   25    Private          11th  ...             0             40      0
# 1   38    Private       HS-grad  ...             0             50      0
# 2   28  Local-gov    Assoc-acdm  ...             0             40      1
# 3   44    Private  Some-college  ...             0             40      1
# 4   18          ?  Some-college  ...             0             30      0
#
# [5 rows x 13 columns]

# %%
print("Proportion of Income Values")
print(df1['income'].value_counts())
df1['income'].value_counts().plot(kind='bar')
print(df1['income'].value_counts(normalize=True) * 100)
# Out:
# Proportion of Income Values
# 0    37155
# 1    11687
# Name: income, dtype: int64
# 0    76.071823
# 1    23.928177
# Name: income, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax=plt.subplots(figsize=(21,14))
sns.heatmap(df1.corr(), annot=True)

# %%
df1 = pd.get_dummies(df1)
df1
# Out:
#        age  educational-num  ...  gender_Female  gender_Male
# 0       25                7  ...              0            1
# 1       38                9  ...              0            1
# 2       28               12  ...              0            1
# 3       44               10  ...              0            1
# 4       18               10  ...              1            0
# ...    ...              ...  ...            ...          ...
# 48837   27               12  ...              1            0
# 48838   40                9  ...              0            1
# 48839   58                9  ...              1            0
# 48840   22                9  ...              0            1
# 48841   52                9  ...              1            0
#
# [48842 rows x 66 columns]

# %%
x=df1.loc[:, df1.columns != 'income']

# %%
from sklearn.model_selection import train_test_split
xtrain , xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
knn3 = KNeighborsClassifier(n_neighbors=33)

knn3.fit(xtrain,ytrain)
print(knn3.score(xtest,ytest))
# Out:
# 0.8602722898966118

# %%
from sklearn.neighbors import KNeighborsClassifier
score_list=[]
score_list2=[]
for i in range(1,20):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(xtrain,ytrain)
    score_list.append(knn.score(xtest,ytest))
plt.plot(range(1,20),score_list)
plt.show()

# %%
score_list2=[]
for i in range(20,40):
    knn2 = KNeighborsClassifier(n_neighbors=i)
    knn2.fit(xtrain,ytrain)
    score_list2.append(knn2.score(xtest,ytest))
plt.plot(range(20,40),score_list2)
plt.show()
